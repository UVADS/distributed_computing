# %% [markdown]
# ## Lab: Semantic Search with Random Projection
# ### University of Virginia
# ### DS 7200: Distributed Computing
# #### Last Updated: April 3, 2024
#
# ---

# %% [markdown]
# #### Instructions
#
# In this assignment, you will use Pinecone as in the notebook `semantic_search.ipynb`, loading in the dataset `quora_all-MiniLM-L6-bm25`
#
# You will study the sensitivity of the results to the random projection method as in the paper:
# [Random Projection in Dimensionality Reduction: Applications to Image and Text Data](https://cs-people.bu.edu/evimaria/cs565/kdd-rp.pdf)
#
# Answer the questions given below, showing all code, reasoning, and results.
# For consistency with the semantic search notebook, use the 80K rows of the dataset between rows 240K -> 320K

# %% [markdown]
# **TOTAL POINTS: 10**
# ***

# %% [markdown]
# **Task 1: RP**
#
# a. Project the text data into a $k$-dimensional subspace, investigating the cases where $k=10$ and $k=100$.
#    You might use the values from the embedding model as a starting point.
#    For each projection matrix, clearly print the dimensions.
#
# b. Given Query 1 below, show the top 5 matches and their associated scores based on cosine distance.
# Discuss how these results differ from `semantic_search.ipynb`.
# The results and discussion are to be shown for both $k=10$ and $k=100$.
#
# Query 1: "which city has the highest population in the world?"
#
# c. Repeat part (c) using Query 2 below:
#
# Query 2: "which metropolis has the highest number of people?"

# %%
# Show code and results

# %% [markdown]
# ---

# %% [markdown]
# **Task 2: Sparse Random Projection (SRP)**
#
# a. Use SRP to project the text data into a $k$-dimensional subspace, investigating the cases where $k=10$ and $k=100$.
#    You might use the values from the embedding model as a starting point.
#    For each projection matrix, clearly print the dimensions.
#
# b. Given Query 2, show the top 5 matches and their associated scores based on cosine distance.
# Discuss how these results compare to those from `semantic_search.ipynb` and the RP method.
# The results and discussion are to be shown for both $k=10$ and $k=100$.

# %%
# Show code and results

# %% [markdown]
# ---

# %% [markdown]
# **Grading Rubric**
#
# Task 1 : RP
# (2 POINTS) Projection matrices calculated and dimensions are correct
# (2 POINTS) Query 1 top matches and scores shown for $k=10$ and $k=100$
# (1 POINT) Discussion of results from Query 1 is clear
# (1 POINT) Query 2 top matches and scores shown for $k=10$ and $k=100$
# (1 POINT) Discussion of results from Query 2 is clear
#
# Task 2 : SRP
# (1 POINT) Projection matrices calculated and dimensions are correct
# (1 POINT) Query 2 top matches and scores shown for $k=10$ and $k=100$
# (1 POINT) Discussion of results from Query 2 is clear
#
# ---
